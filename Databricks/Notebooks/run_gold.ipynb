# %%
import sys
import importlib
sys.path.append("/Workspace/Shared/Capstone")
import utils
importlib.reload(utils)

from gold_engine import GoldEngine
importlib.reload(GoldEngine)
print("Starting Gold")
GoldEngine(spark).run()
